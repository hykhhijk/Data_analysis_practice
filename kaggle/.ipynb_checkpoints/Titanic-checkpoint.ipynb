# %%
# !kaggle competitions download -c titanic
# Out:
# ...
#   0%|          | 0.00/34.1k [00:00<?, ?B/s]
# 100%|##########| 34.1k/34.1k [00:00<00:00, 34.8MB/s]

# %%
import pandas as pd

# %%
train_df = pd.read_csv("titanic/train.csv")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(train_df[train_df["Survived"]==0].Age, bins=20)
plt.show()

# %%
plt.hist(train_df[train_df["Survived"]==1].Age, bins=20)
plt.show()

# %%
plt.hist(train_df[train_df["Survived"]==0 ].Pclass,bins=5)
plt.ylim([0, 400])
plt.show()

# %%
plt.hist(train_df[train_df["Survived"]==1 ].Pclass, bins=5)
plt.ylim([0, 400])
plt.show()

# %%
plt.hist(x = [train_df[train_df['Survived']==1].Fare, train_df[train_df['Survived']==0].Fare], stacked=True)
plt.show()
